# %%
# !git clone https://github.com/lihas/colab-notebooks.git
# Out:
# fatal: destination path 'colab-notebooks' already exists and is not an empty directory.

# %%
#code taken from https://github.com/imneonizer/How-to-find-if-an-image-is-bright-or-dark

# %%
import os
import glob
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def getbright(image, dim=10, thresh=0.5):
    # Resize image to 10x10
    image = cv2.resize(image, (dim, dim))
    # Convert color space to LAB format and extract L channel
    L, A, B = cv2.split(cv2.cvtColor(image, cv2.COLOR_BGR2LAB))
    # Normalize L channel by dividing all pixel values with maximum pixel value
    #L = L/np.max(L)
    # Return True if mean is greater than thresh else False
    npm = np.mean(L)
    print(npm)
    return npm

# %%
# load image freom disk
print("new")
image1 = cv2.imread("colab-notebooks/PhillipsH4RacingVisionVsHalonixBrightnessComparison/new.jpg")
image = image1
# find if image is bright or dark
newBr = getbright(image)

print("old")
image2 = cv2.imread("colab-notebooks/PhillipsH4RacingVisionVsHalonixBrightnessComparison/old.jpg")
image = image2

# find if image is bright or dark
oldBr = getbright(image)

print("percentage difference", ((newBr - oldBr)/oldBr)*100, "%\n\n")

# write text on image
#cv2.putText(image, "{}".format(text), (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 0, 255), 2)

# show image
print("new image:")
plt.figure(figsize=(10,10))
plt.imshow(cv2.cvtColor(image1, cv2.COLOR_BGR2RGB))
plt.show()

print("old image:")
plt.figure(figsize=(10,10))
plt.imshow(cv2.cvtColor(image2, cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# new
# 22.29
# old
# 18.06
# percentage difference 23.421926910299007 %
#
#
# new image:
# old image:
